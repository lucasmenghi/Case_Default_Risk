# %% [markdown]
# ## **Home Credit Default Risk**

# %% [markdown]
# ### **Description**

# %% [markdown]
# Link Business Problem:  https://www.kaggle.com/competitions/home-credit-default-risk

# %% [markdown]
# Many people struggle to get loans due to insufficient or non-existent credit histories. And, unfortunately, this population is often taken advantage of by untrustworthy lenders.
#
# Home Credit Group
#
# Home Credit strives to broaden financial inclusion for the unbanked population by providing a positive and safe borrowing experience. In order to make sure this underserved population has a positive loan experience, Home Credit makes use of a variety of alternative data--including telco and transactional information--to predict their clients' repayment abilities.
#
# While Home Credit is currently using various statistical and machine learning methods to make these predictions, they're challenging Kagglers to help them unlock the full potential of their data. Doing so will ensure that clients capable of repayment are not rejected and that loans are given with a principal, maturity, and repayment calendar that will empower their clients to be successful.

# %% [markdown]
# ### **Evaluation**

# %% [markdown]
# Submissions are evaluated on area under the ROC curve between the predicted probability and the observed target.
#
# **Submission File**
# For each SK_ID_CURR in the test set, you must predict a probability for the TARGET variable. The file should contain a header and have the following format:

# %%
SK_ID_CURR,TARGET
100001,0.1
100005,0.9
100013,0.2

# %% [markdown]
# ### **Conclusões Finais**

# %% [markdown]
# Estamos trabalhando em uma empresa que oferta crédito para os clientes e o ponto principal de oportunidade do negócio é o volume de clientes que possuem dificuldades de aprovação de empréstimos por conta de um histórico de crédito insuficiente ou inexistente. Caindo em muitos golpes no processo.
#
# Dito isso, nossa principal ambição nesse contexto é garantir que a população com **histórico peculiar** possua acesso a crédito de maneira segura e eficiente.
